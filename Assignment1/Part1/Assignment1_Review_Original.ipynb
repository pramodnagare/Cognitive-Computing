# %% [markdown]
# '''Trains a simple deep NN on the MNIST dataset.
# Gets to 98.40% test accuracy after 20 epochs
# (there is *a lot* of margin for parameter tuning).
# 2 seconds per epoch on Colab with Hardware Accelarator: TPU.
# '''

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 8s 1us/step

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.2485 - acc: 0.9234 - val_loss: 0.1025 - val_acc: 0.9688
# Epoch 2/20
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.1032 - acc: 0.9681 - val_loss: 0.0785 - val_acc: 0.9756
# Epoch 3/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0741 - acc: 0.9776 - val_loss: 0.0736 - val_acc: 0.9786
# Epoch 4/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0598 - acc: 0.9819 - val_loss: 0.0707 - val_acc: 0.9804
# Epoch 5/20
# 60000/60000 [==============================] - 11s 186us/step - loss: 0.0505 - acc: 0.9845 - val_loss: 0.0667 - val_acc: 0.9809
# Epoch 6/20
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0428 - acc: 0.9870 - val_loss: 0.0705 - val_acc: 0.9828
# Epoch 7/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0384 - acc: 0.9886 - val_loss: 0.0679 - val_acc: 0.9835
# Epoch 8/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0348 - acc: 0.9900 - val_loss: 0.0811 - val_acc: 0.9827
# Epoch 9/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0309 - acc: 0.9908 - val_loss: 0.0715 - val_acc: 0.9847
# Epoch 10/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0281 - acc: 0.9915 - val_loss: 0.0688 - val_acc: 0.9853
# Epoch 11/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0275 - acc: 0.9923 - val_loss: 0.0967 - val_acc: 0.9802
# Epoch 12/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0250 - acc: 0.9927 - val_loss: 0.0904 - val_acc: 0.9820
# Epoch 13/20
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0240 - acc: 0.9932 - val_loss: 0.0964 - val_acc: 0.9829
# Epoch 14/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0225 - acc: 0.9937 - val_loss: 0.1003 - val_acc: 0.9830
# Epoch 15/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0223 - acc: 0.9937 - val_loss: 0.0927 - val_acc: 0.9830
# Epoch 16/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0205 - acc: 0.9945 - val_loss: 0.0979 - val_acc: 0.9847
# Epoch 17/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0211 - acc: 0.9944 - val_loss: 0.0966 - val_acc: 0.9840
# Epoch 18/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0221 - acc: 0.9944 - val_loss: 0.1100 - val_acc: 0.9832
# Epoch 19/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0187 - acc: 0.9948 - val_loss: 0.1111 - val_acc: 0.9840
# Epoch 20/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0186 - acc: 0.9954 - val_loss: 0.1305 - val_acc: 0.9815

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
print('Test loss:', score[0])
# Out:
# Test loss: 0.1199758258390787

# %%
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.9828

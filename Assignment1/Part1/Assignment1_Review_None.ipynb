# %% [markdown]
# '''Trains a simple deep NN on the MNIST dataset.
# Gets to 98.29% test accuracy after 20 epochs
# (there is *a lot* of margin for parameter tuning). 11 seconds per epoch on a Colab Hardware Accelarator : None.
# '''

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.2472 - acc: 0.9237 - val_loss: 0.1239 - val_acc: 0.9607
# Epoch 2/20
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.1039 - acc: 0.9677 - val_loss: 0.0805 - val_acc: 0.9757
# Epoch 3/20
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0736 - acc: 0.9783 - val_loss: 0.0990 - val_acc: 0.9702
# Epoch 4/20
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0604 - acc: 0.9813 - val_loss: 0.0772 - val_acc: 0.9808
# Epoch 5/20
# 60000/60000 [==============================] - 12s 203us/step - loss: 0.0505 - acc: 0.9846 - val_loss: 0.0737 - val_acc: 0.9830
# Epoch 6/20
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0422 - acc: 0.9871 - val_loss: 0.0838 - val_acc: 0.9809
# Epoch 7/20
# 60000/60000 [==============================] - 12s 202us/step - loss: 0.0385 - acc: 0.9888 - val_loss: 0.0783 - val_acc: 0.9832
# Epoch 8/20
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0353 - acc: 0.9898 - val_loss: 0.0948 - val_acc: 0.9806
# Epoch 9/20
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0300 - acc: 0.9909 - val_loss: 0.0931 - val_acc: 0.9824
# Epoch 10/20
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0281 - acc: 0.9916 - val_loss: 0.1040 - val_acc: 0.9809
# Epoch 11/20
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0266 - acc: 0.9923 - val_loss: 0.0949 - val_acc: 0.9821
# Epoch 12/20
# 60000/60000 [==============================] - 11s 187us/step - loss: 0.0242 - acc: 0.9933 - val_loss: 0.1041 - val_acc: 0.9819
# Epoch 13/20
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0229 - acc: 0.9936 - val_loss: 0.1033 - val_acc: 0.9819
# Epoch 14/20
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0209 - acc: 0.9940 - val_loss: 0.1151 - val_acc: 0.9818
# Epoch 15/20
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0212 - acc: 0.9941 - val_loss: 0.0974 - val_acc: 0.9845
# Epoch 16/20
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0203 - acc: 0.9944 - val_loss: 0.1160 - val_acc: 0.9820
# Epoch 17/20
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0198 - acc: 0.9948 - val_loss: 0.1132 - val_acc: 0.9818
# Epoch 18/20
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.0182 - acc: 0.9951 - val_loss: 0.1127 - val_acc: 0.9827
# Epoch 19/20
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0170 - acc: 0.9954 - val_loss: 0.1116 - val_acc: 0.9844
# Epoch 20/20
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0159 - acc: 0.9953 - val_loss: 0.1179 - val_acc: 0.9829

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
print('Test loss:', score[0])
# Out:
# Test loss: 0.1179096469444896

# %%
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.9829

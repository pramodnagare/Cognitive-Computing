# %% [markdown]
# '''Trains a simple deep NN on the MNIST dataset.
# Gets to 98.42% test accuracy after 20 epochs
# (there is *a lot* of margin for parameter tuning).
# 2 seconds per epoch on a Colab Hardware accelrator: GPU.
# '''

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.2456 - acc: 0.9249 - val_loss: 0.1201 - val_acc: 0.9612
# Epoch 2/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1017 - acc: 0.9689 - val_loss: 0.1059 - val_acc: 0.9673
# Epoch 3/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0745 - acc: 0.9772 - val_loss: 0.0830 - val_acc: 0.9762
# Epoch 4/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0592 - acc: 0.9826 - val_loss: 0.0743 - val_acc: 0.9799
# Epoch 5/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0496 - acc: 0.9852 - val_loss: 0.0718 - val_acc: 0.9817
# Epoch 6/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0439 - acc: 0.9871 - val_loss: 0.0706 - val_acc: 0.9816
# Epoch 7/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0389 - acc: 0.9887 - val_loss: 0.0770 - val_acc: 0.9803
# Epoch 8/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0342 - acc: 0.9902 - val_loss: 0.0910 - val_acc: 0.9809
# Epoch 9/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0296 - acc: 0.9910 - val_loss: 0.0901 - val_acc: 0.9813
# Epoch 10/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0285 - acc: 0.9919 - val_loss: 0.0925 - val_acc: 0.9816
# Epoch 11/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0251 - acc: 0.9929 - val_loss: 0.0926 - val_acc: 0.9809
# Epoch 12/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0261 - acc: 0.9928 - val_loss: 0.0882 - val_acc: 0.9831
# Epoch 13/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0227 - acc: 0.9932 - val_loss: 0.1105 - val_acc: 0.9795
# Epoch 14/20
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0213 - acc: 0.9943 - val_loss: 0.0919 - val_acc: 0.9836
# Epoch 15/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0207 - acc: 0.9945 - val_loss: 0.1051 - val_acc: 0.9832
# Epoch 16/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0213 - acc: 0.9942 - val_loss: 0.0993 - val_acc: 0.9832
# Epoch 17/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0206 - acc: 0.9945 - val_loss: 0.0872 - val_acc: 0.9860
# Epoch 18/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0210 - acc: 0.9952 - val_loss: 0.1073 - val_acc: 0.9829
# Epoch 19/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0191 - acc: 0.9954 - val_loss: 0.1121 - val_acc: 0.9834
# Epoch 20/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0185 - acc: 0.9950 - val_loss: 0.1000 - val_acc: 0.9842

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
print('Test loss:', score[0])
# Out:
# Test loss: 0.0999793513472428

# %%
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.9842

# %%
# libraries imported 

from bs4 import BeautifulSoup
import urllib
import PIL
from PIL import Image
import shutil
#!pip install patool
import patoolib
from os import listdir
from os.path import isfile, join

# %%
# url for gun

main_url = "http://www.imfdb.org/wiki/Category:Gun"
gun_page = urlopen(main_url)
category = BeautifulSoup(gun_page)
# Out:
# C:\Users\Dell-pc\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Dell-pc\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
categories = category.findAll('a')

# %%
#for different categories 

c = categories[37:61]
ctg = []
for i in range(len(c)):
    q = str(c[i]).split('/')[2].split('" title')[0]
    ctg.append(q)

# %%
ctg[0]
# Out:
# 'Category:Assault_Rifle'

# %%
#imgs = soup.findAll("div",{'class':'thumb'})
url = "http://www.imfdb.org/wiki/"+ctg[0]
url
# Out:
# 'http://www.imfdb.org/wiki/Category:Assault_Rifle'

# %%
#guns = []
#import os
#for img in imgs:
#        images = (img.a['href'].split("imgurl=")[0])
        #urllib.request.urlretrieve(img,img_save)
#        guns.append(images)

# %%
# path to save the imgaes

path = r"C:\Users\Dell-pc\Desktop\Dataset_Final"
try:  
    os.mkdir(path)
except OSError:  
    print ("Creation of the directory %s failed" % path)
else:  
    print ("Successfully created the directory %s " % path)
# Out:
# Creation of the directory C:\Users\Dell-pc\Desktop\Dataset_Final failed

# %%
#saving the images 

for i in range(len(ctg)):

    url = "http://www.imfdb.org/wiki/"+ ctg[i]
    path = r"C:\Users\Dell-pc\Desktop\Dataset_Final"
    guns = urlopen(url)

    guns = BeautifulSoup(guns)
    for res in guns.findAll('img'):
        list_var = url.split('/')
        link = urlopen(list_var[0]+"//"+list_var[2]+res.get('src'))
        output = open(path + '\\' + res.get('src').split('/')[-1],"wb")
        output.write(link.read())
        output.close()
# Out:
# C:\Users\Dell-pc\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Dell-pc\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
#unrar the knife files

url = 'http://kt.agh.edu.pl/matiolanski/KnivesImagesDatabase/KnivesImagesDatabase.rar'
file_name = 'knife.rar'

with urllib.request.urlopen(url) as response, open(file_name, 'wb') as out_file:
    shutil.copyfileobj(response, out_file)
    #with zipfile.ZipFile(file_name) as zf:
     #   zf.extractall()

# %%
patoolib.extract_archive("knife.rar", outdir=r"C:\Users\Dell-pc\DEEP LEARNING")

# %%
knife_dataset = r'C:\\Users\\Dell-pc\\DEEP LEARNING\\KnivesImagesDatabase\\POSITIVES_ALL'

# %%
from os import listdir
from os.path import isfile, join
knives = [pictures for pictures in listdir(knife_dataset) if isfile(join(knife_dataset, pictures))]

# %%
path = r"C:\Users\Dell-pc\Desktop\Knives"
try:  
    os.mkdir(path)
except OSError:  
    print ("Creation of the directory %s failed" % path)
else:  
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory C:\Users\Dell-pc\Desktop\Knives

# %%
for i in range(len(knives)):
    img = Image.open(knife_dataset+"\\" + knives[i])
#new_img = img.resize( (100, 256) )
    img.save(r"C:\Users\Dell-pc\Desktop\Knives" +"\\" + str(i) + ".jpg")

# %%
path = r"C:\Users\Dell-pc\Desktop\Resized_gun"
try:  
    os.mkdir(path)
except OSError:  
    print ("Creation of the directory %s failed" % path)
else:  
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory C:\Users\Dell-pc\Desktop\Resized_Knife

# %%
# reshaping the pictures 

path = r"C:\Users\Dell-pc\Desktop\Gun_without_grenade"

pics = [pictures for pictures in listdir(path) if isfile(join(path, pictures))]

for i in range(len(pics)):
    basewidth = 200
    baseheight = 200
    img = Image.open(r"C:\Users\Dell-pc\Desktop\Gun_without_grenade" +"\\" + pics[i])
    wpercent = (basewidth / float(img.size[0]))
    hpercent = (baseheight / float(img.size[1]))
    img = img.resize((basewidth, baseheight), PIL.Image.ANTIALIAS)
    rgb_im = img.convert('RGB')
    rgb_im.save(r"C:\Users\Dell-pc\Desktop\resized_gun" +"\\" +'g' + str(i) + ".jpg")

# %%
pics
# Out:
# ['103px-Model_7290T.jpg',
#  '105px-9K115-2.jpg',
#  '105px-MS_Redback.jpg',
#  '106px-M17-Ehg.jpg',
#  '107px-Thermos.jpg',
#  '108px-No_34.jpg',
#  '109px-M47_Dragon.jpg',
#  '109px-Mk20_91.jpg',
#  '110px-Fakel-S.jpeg',
#  '112px-Model_7290.jpg',
#  '114px-Flak30.jpg',
#  '115px-GAU-17A_HH60.jpg',
#  '116px-B-10-82mm-recoilles-rifle-batey-haosef-1-1.jpg',
#  '116px-L132A1.jpg',
#  '119px-Model_5210_White_Smoke.jpg',
#  '119px-RGR_grenade.jpg',
#  '120px-Javalin.jpg',
#  '120px-Zastava_M55_Triple_20mm.jpg',
#  '123px-MK3A2.jpg',
#  '124px-Citron1916.jpg',
#  '125px-M52P2.jpg',
#  '126px-M84-Flash-Bang-Grenade.jpg',
#  '127px-GasGrenadeMk.jpg',
#  '128px-Japanese-type97-grenade.jpg',
#  '128px-M7A3.jpg',
#  '128px-RG-42_HG.jpg',
#  '129px-M18red.jpg',
#  '130px-BaktarShikan3.jpg',
#  '130px-Tow_07.jpg',
#  '131px-AN-M8.jpg',
#  '131px-VickersMk1.jpg',
#  '132px-IngramMAC10.jpg',
#  '132px-TDMultiPortPlusFlashbang.jpg',
#  '133px-M52P1.jpg',
#  '133px-Type90Version3Flare.jpg',
# ...
